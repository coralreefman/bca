# %% [markdown]
# # Reader Computational Art
# A collection of texts about art and computation.

# %% [markdown]
# *“In the computer field, the moment of truth is a
# running program; all else is prophecy.”*
# Herbert Simon
#
# **code** (kod) ...
# 3.a. A system of signals used to represent letters or numbers in
# transmitting messages.
# b. A system of symbols, letters, or words given certain
# arbitrary meanings, used for transmitting messages
# requiring secrecy or brevity.
# -4. A system of symbols and rules used to represent instructions
# to a computer…
# — The American Heritage Dictionary of the English Language
# From [Code - The Hidden Language of Computer Hardware and Software](https://home.artelse.com:15001/sharing/Q3G3gGzPe)
# Charles Petzold
#
# ### Download link for books:
# https://drive.proton.me/urls/1GBDAN1TYG#GL9GjXUXBWQM
# (expires by end of November)

# %% [markdown]
# ### Read before Tuesday's class:
# Hui, Yuk - The Computational Turn or a New Weltbild

# %% [markdown]
# ## The Black Box & The Problem of Digitalization
#
# In the analog realm, cause and effect are a continuum; when a string is plucked on an acoustic musicial instrument like a guitar for example it sets air in vibration. We perceive this as sound; an everyday physical phenomenon.
# However, in the digital realm, an physical event is broken down into a stream of numbers, becoming discrete instead of continuous. This allows for the initial input to be mapped onto any possible output. The clear causal relationship between input and output has been lost. This requires utmost responsibility of the artist to define meaningful relationships.
#
# Following texts expand on these notions.
#
# ### Jean-François Lyotard in Les Immatériaux:
# **Digital versus Sublime**
#
# Many new technological inventions and artificial materials have changed this relationship of man to material reality, but for Lyotard the most fundamental and dramatic change has been introduced by the digital technologies.
#
# Two things are important here: Lyotard maintains that we first of all relate to reality through the messages we receive from the outside environment. In the post-industrial societies these
# messages have become increasingly mediated. It is, however, a characteristic of mediation that the messages communicated through that medium have to be translated into the code of that particular medium. The digital technologies signify a fundamental break. All
# messages, regardless of their origin or constitution (image, sound, text, data, etc..) have to be translated into one universal code of digital information; the process of digitalisation.
#
# In order to be able to process the information with a digital system the information has to be atomised, broken up into fundamental smallest units out of which every message is composed. Atomisation of information involves the need for a complete description of the phenomenon in terms of these smallest units. What falls outside of this description, because for example it is to small to be measured, is disregarded. Something of the original source-information is always lost in this process of atomisation and digitalisation of information. "It is as if a filter has been placed between us and the things, a screen of numbers", Lyotard
# writes in the press-release to Les Immatériaux. 2
#
# These are exactly the two consequences Lyotard takes to be crucial to the problems that are posed by the 'Immaterials'. In an interview taken in May 1988 he re-stated the problem:
#
# "The media are intended to close the system within itself, by incorporating the exteriorities in the system. As in 'Mother', 'mat' (from: 'maternité'= motherhood in French) signifies something which has given birth, so something which constitutes the secret of existence, and seems to be similar to the media in that sense. But the exteriority is preserved. This exteriority is found at the origin and is lost, it is however lost as an origin. The immaterials signify the loss of this lost thing. It is as if there is no origin at all. The important point is the incorporation of the exteriorities in the system, not just in the system of the media, but also of the techno-sciences in general. The consequence is that everything becomes a message, even the silence that strictly speaking does not tell anything, does not exist. "Mother" entails basically the concept that something has been lost (the origin), that its disappearance does not tell anything, but generates meaning." 3
#
# (And in this sense the new technologies are not sublime)
#
# We can now return to the main question of the manifestation: "Do the 'Immaterials' change the relation of man to the material as it has been formulated in the modern tradition, for example by the Cartesian program: 'to become master and proprietor of nature ?"
#
# Now the material is not just that on which human activity is acted out, it also entails a net of associations and polarities that determine how we relate to the world. Primary associations are; material versus spiritual, matter versus mind, matter versus energy, matter versus form, matter versus product. New materials change not only the conception of the materials as such but also this net of associations.
#
# To intensify the main-question, the manifestation chose to undermine "..the indolent modern prejudice that the new materials maximise the control of man over nature", by presenting disturbing views. (...) What is disturbing for man is that his (purported) identity as a human being is slipping from him. The substantive adjective "Human" signifies an old domain of knowledge and skills, which is now shared by the techno-sciences, that are breaking open this terrain. They are discovering and expanding analog (but generally more complex) immaterials to those (purported) human skills."
#
# The formerly mute materials are now performing human tasks, and often are even better at it (calculations, robotic assemblage etc..). For Lyotard the consequence of this development is that man has to face his place in the universe as being part of this material world. Man's privileged position as the sole cognoscente being is lost, while she/he is confronted with a reality that is to complex to comprehend and control. "Consequently, the views associated with the concept of the "Material", that feed the immediate awareness of an identity as human, have become weaker. Notably: Experience, memory, work, autonomy (or freedom), even 'creation' and in general the difference with that which is not human. The feeling of a general interaction, however is intensified."
#
# This anxiety causes the desire for a new and stable identity, which according to Lyotard can take on thousand forms and sometimes even the form "post-modern".
#
# Notes:
# 1- Jean François Lyotard & Thierry Chaput, Les Immatériaux - Conception, Centre de Creation Industrielle / Centre Georges Pompidou, Paris, March 1985. Republished (a.o.) in: J.F. Lyotard mit anderen, Immaterialität und Postmoderne, Merve Verlag, Berlin, 1985.The last book also contains the original press release (in German translation) and interviews with Lyotard, Chaput and François Burkhardt.
#
# 2 - Nelson Goodman has explained this point in his treatment of analog and digital systems in: The Theory of Notation - Analogs and Digits, in: Languages of Art - An Approach to a Theory of Symbols, Hackett Publishing Company, Indianapolis, 1976, pp. 159-164.
#
# 3 - J.F. Lyotard in conversation with Christine Spies (6.5.1988), Die Erhabenheit ist das Unkonsumierbare, in: Kunstforum int., Kunst und Philosophie, Köln, 1990
#
# ### Lev Manovich on Digitalization
#
# "These works also direct us to the map – the abstract space of possible transformations between signals. That domain of transformation is also inframedial, a key structure in digital media forms and cultures. Lev Manovich (2002) has described this question as the “built-in existential angst” of digital media: “By allowing us to map anything into anything else ... computer media simultaneously makes all these choices appear arbitrary….” In almost all digital media, the map – the pattern of relations between input and output – is imperceptible, obscured or encoded. This is clearest in the work of artists working explicitly with data inputs. In the work of Alex Drauglescu for example, spam email is used as the input to an algorithm that creates complex three dimensional forms. The mapping – the process that transforms spam into form – is never revealed, and so a concrete, specific process becomes a blank spot filled in with an impression of magical transubstantiation. In some computational work the artist provides source code, an explicit specification of the map but one that is highly encoded and unavailable, in itself, to perception. In most digital media objects, the map is inextricable from the residue or artefact it shapes. We perceive only the output, the image, sound or form, in which the input and its transformations are collapsed."
#
# Taken from Mitchell Whitelaw on SYNESTHESIA AND CROSS-MODALITY IN CONTEMPORARY AUDIOVISUALS
# http://www.teemingvoid.blogspot.co.at/2008/10/synesthesia-and-cross-modality-in.html
#
# ### Les Immatériaux texts
# https://coolmin.stackstorage.com/s/wWOpis7RfiV6zdk/en_US
#
# ### The New Landscape in Art and Science
# Gyorgy Kepes

# %% [markdown]
# ### Manovich on the "anti-sublime"
# Manovic, Lev - Data Visualization as New Abstraction and Anti-Sublime

# %% [markdown]
# Donald Knuth## Art and Computation
#
# Art and Computation
# A new book by Miguel Carvalhais
#
# His previous book is much more comprehensive:
# Artificial Aesthetics - Creative Practices in Computational Art and Design
#
# ### Generative Art
# *Intro recent generative work*
# Quickstart to Generative Art by Sabine Wieluch, Artist, bleeptrack
# https://githubuniverse.com/Exploring-generative-spaces-a-quickstart-to-generative-art/
#
# [What Is Generative Art? - Complexity Theory as a Context for Art Theory](https://home.artelse.com:15001/sharing/X1xbg11dZ)
# by Philip Galanter
#
# [What Is Generative Art?](https://home.artelse.com:15001/sharing/8rAS5jSVx)
# by Margaret Boden and Ernest Edmonds
#
# ---
# ### Permutation
# In music one might look at the music of composer Tom Johnson.
# In [Looking at Numbers](https://home.artelse.com:15001/sharing/bW5ryhl23) chapter one an in depth discussion about permutations that are beautifully illustrated by drawings.
# And on the tube: https://www.youtube.com/watch?v=Nx-_uigeR_Q
#
# ---
# ### Recursion and Iteration
#
# [How Recursion Works](https://www.freecodecamp.org/news/how-recursion-works-explained-with-flowcharts-and-a-video-de61f40cb7f9/)
#
# Or better watch this explanation in python and learn about the Fibonacci sequence:
# https://youtu.be/Qk0zUZW-U_M
#
# *A recursive book*
# The Little LISPer - Daniel P. Friedman, Matthias Felleisen
# And the updated The Little Schemer and The Seasoned Schemer
# The Little LISPer is self-contained: an interpreter for the language is developed using the tools of the book itself.
#
# *Recursion humour*
# https://recursivelyrecursive.files.wordpress.com/2019/11/ekerbopwoaat-qc.jpg
# Look up some more on the net :)
#
# ---
# ### Grammars
#  [Aaron - Harold Cohen](http://www.aaronshome.com/aaron/index.html)
#  [How to draw three people in a botanical garden](https://home.artelse.com:15001/sharing/HunizqDFW) [paper]
# Harold Cohen
#  [Graffitizer - Daniel Berio](https://www.enist.org/post/)
#
# ---
# ### Generative Poetry
# William Burroughs (cutup techniques (permutations))
#
# Gustav Metzger in Mainframe Experimentalism
# by Douglas Kahn
#
# *Uncreative Writing*
# Kenneth Goldsmith
#
# [You shall not pass](https://youshallnotpass.glitch.me)
# https://twitter.com/predartbot
# http://predictiveartbot.com/
#
# ---
# ### Early computer art (50s 60s)
#
# Vera Molnár, Desmond Paul Henry, Frieder Nake, Georg Nees, Michael Noll,Sonia Sheridan, Harold Cohen
# *The Anthology of Computer Art*
# Sonic Acts XI (hard copy)
#
# A. Michael Noll
# early pioneer of computer art (graphic mostly)
# http://dada.compart-bremen.de/item/agent/16
#
# Computer Ballet
# Bell Labs 1968
# https://youtu.be/phVN_HS5Fy8
#
# ---
# ### Data
# [Data is Nature](dataisnature.com/)
# Paul Prudence's eclectic collection of visuals
#
# ---
# ### AI and ML
# Edward Ihnatowicz - [The Senster](http://senster.org/)
# [The Relevance of Manipulation to the Process of Perception](http://www.senster.com/ihnatowicz/articles/relevance_manipulation.pdf)

# %% [markdown]
# ## Data sets
#
# Need a collection of hugs and kisses, a huge collection of New York Times articles?
# https://academictorrents.com
#
# Text corpora
# https://github.com/dariusk/corpora/tree/master/data
#
# Data from around the world
# http://datacatalogs.org/
#
# Elon Musk's sentiment tweets in relation to world happiness and suicide rates?
# https://www.kaggle.com/datasets/alexhuggler/elon-tweets-wsentimentclassified-via-roberta?select=ElonTweets%28Sentiment%29.csv
#
# ccc - data mining
# https://www.youtube.com/watch?v=-YpwsdRKt8Q
#
# Agent Radio webscraping example

# %% [markdown]
# ## Inspiration
# Generate quoatble quotes.
# https://inspirobot.me/
#
# Twitter bots and such
# http://tinysubversions.com/
#
# William Latham, the infamous computer artist
# [TED talk](https://youtu.be/MZGOr94468w)
# [Mutations](https://youtu.be/7sadS5wuOjU)
# [Sequence from The Evolution of Form](https://youtu.be/x-S9iOF0uMI)
# https://www.youtube.com/watch?v=OYN8mZ5nCQY
#
# Data into physical
# https://christopherbaker.net/projects/murmur-study/
#
# Zach Lieberman
# https://twitter.com/i/status/1346225399458652160
#
# William Burroughs Cutup Example
# https://cdn.wallpaper.com/main/styles/responsive_770w_scale/s3/legacy/gallery/17053788/03_WilliamBurroughs.jpg
#
# Golan Levin on the modulo operator
# https://www.youtube.com/watch?v=r5Iy3v1co0A
# and on interpolation
# https://youtu.be/mvgcNOX8JGQ
#
# *Conway's Game of Life*
# [Online playground](https://playgameoflife.com/lexicon/2-glider_mess)
#
# *Genetic Algorithms*
# [Carl Sims](https://www.youtube.com/watch?v=bBt0imn77Zg)
#
# *Megan Daalder: Tribute to Carl Sims*
# [Primordial Futures](https://primordialfutures.com/TRIBUTE-TO-KARL-SIMS)
#
# *Cellular Automata*
# [A New Kind of Science (2002)](https://home.artelse.com:15001/sharing/rAFqs3jAL)
# Stephen Wolfram
#
# *Picbreeder*
# [Evolutionary Art with Picbreeder](http://picbreeder.org/)
#
# *Artbreeder*
# [A Contemporary Approach to Evolutionary Art in the Browser](https://www.artbreeder.com/)
#
# *Harm van den Dorpel*
# [Example of Contemporary Art using Genetic Algorithms](https://mutant.garden/)
#
# *Ian Cheng*
# [A Different Approach using Simulation](https://www.moma.org/calendar/exhibitions/3656)
#
# *The Art of Bots*
# A Practice-based Study of the Multiplicity, Entanglements and Figuration of Sociocomputational Assemblages (2018)
# by Plummer-Fernandez, Matthew (PDF at drive)

# %% [markdown]
# ## tbd
#
# *Gerard 't Hooft and Cellular Automata*
# [Cellular Automaton Interpretation of Quantum Mechanics (pdf) ](https://link.springer.com/content/pdf/10.1007%2F978-3-319-41285-6.pdf)
#
# https://arxiv.org/abs/1405.1548
#
# "When investigating theories at the tiniest conceivable scales in nature, almost all researchers today revert to the quantum language, accepting the verdict from the Copenhagen doctrine that the only way to describe what is going on will always involve states in Hilbert space, controlled by operator equations. Returning to classical, that is, non quantum mechanical, descriptions will be forever impossible, unless one accepts some extremely contrived theoretical constructions that may or may not reproduce the quantum mechanical phenomena observed in experiments.
# Dissatisfied, this author investigated how one can look at things differently. This book is an overview of older material, but also contains many new observations and calculations. Quantum mechanics is looked upon as a tool, not as a theory. Examples are displayed of models that are classical in essence, but can be analysed by the use of quantum techniques, and we argue that even the Standard Model, together with gravitational interactions, might be viewed as a quantum mechanical approach to analyse a system that could be classical at its core. We explain how such thoughts can conceivably be reconciled with Bell's theorem, and how the usual objections voiced against the notion of `superdeterminism' can be overcome, at least in principle. Our proposal would eradicate the collapse problem and the measurement problem. Even the existence of an "arrow of time" can perhaps be explained in a more elegant way than usual.
# Discussions added in v3: the role of the gravitational force, a mathematical physics definition of free will, and an unconventional view on the arrow of time, amongst others."
#
#
# --
#
# "Gerard ’t Hooft in recent years has been pursuing some idiosyncratic ideas about quantum mechanics; for various versions of these, see papers like this, this, this and this. His latest version is last month’s Discreteness and Determinism in Superstrings, which starts with cellular automata in 1+1 dimensions and somehow gets a quantized superstring out of it (there are also some comments about this on his web-site here)."
#
# more: https://www.math.columbia.edu/~woit/wordpress/?p=5022
#
# --
#
# August 13, 2012 at 6:24 pm, Gerard 't Hooft *responds*:
#
# Even though my work is here sketched as “not even wrong”, I will avoid any glimpse of hostility, as requested; I do think I have the right to say something here in my defense (One positive note: “Not even wrong” sounds a little bit better than “Wrong wrong wrong” on another blog …).
#
# ```First, I agree that cellular automata doesn’t sound very sexy; those who have seen Wolfram’s book will certainly be discouraged.``` But I want to stress as much as I can that I am striving at a sound and interesting mathematical basis to what I am doing; least of all I would be tempted to throw away any of the sound and elegant mathematics of quantum mechanics and string theory. Symmetries, representation theory, and more, will continue to be central themes.
#
# I am disappointed about the reception of my paper on string theory, as I was hoping that it would open some people’s eyes. Perhaps it will, if some of my friends would be prepared to put their deeply rooted scepsis against the notion of determinism on hold.
# I think the mathematics I am using is interesting and helpful. I encounter elliptic theta functions, and hit upon an elegant relation between sets of non-commuting operators p and q on the one hand, with integer, commuting variables P and Q on the other. All important features of Quantum Mechanics are kept intact as they should.
#
# I did not choose to side with Einstein on the issue of QM, it just came out that way, I can’t help that. It is also not an aversion of any kind that I would have against Quantum Mechanics as it stands, it is only the interpretation where I think I have non-trivial observations.
# If you like the many world interpretation, or Bohm’s pilot waves, fine, but I never thought those have anything to do with the real world; my interpretation I find far superior, but I just found out from other blogs as well as this one, that most people are not ready for my ideas. Since the mud thrown at me is slippery, it is hard to defend my ideas but I think I am making progress.
#
# They could well lead to new predictions, such as a calculable string coupling constant g_s, and (an older prediction) the limitations for quantum computers. They should help investigators to understand what they are doing when they discuss “quantum cosmology”, and eventually, they should be crucial for model building.
#
# G. ’t H
