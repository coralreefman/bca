# %%
# !pip install opencv-python Pillow scikit-image
# Out:
# Requirement already satisfied: opencv-python in /home/carl69/anaconda3/envs/jupyter/lib/python3.9/site-packages (4.6.0.66)
# Requirement already satisfied: Pillow in /home/carl69/anaconda3/envs/jupyter/lib/python3.9/site-packages (9.2.0)
# Requirement already satisfied: scikit-image in /home/carl69/anaconda3/envs/jupyter/lib/python3.9/site-packages (0.19.3)
# Requirement already satisfied: numpy>=1.19.3 in /home/carl69/anaconda3/envs/jupyter/lib/python3.9/site-packages (from opencv-python) (1.23.4)
# Requirement already satisfied: scipy>=1.4.1 in /home/carl69/anaconda3/envs/jupyter/lib/python3.9/site-packages (from scikit-image) (1.9.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/carl69/anaconda3/envs/jupyter/lib/python3.9/site-packages (from scikit-image) (2022.10.10)
# Requirement already satisfied: networkx>=2.2 in /home/carl69/anaconda3/envs/jupyter/lib/python3.9/site-packages (from scikit-image) (2.8.7)
# Requirement already satisfied: imageio>=2.4.1 in /home/carl69/anaconda3/envs/jupyter/lib/python3.9/site-packages (from scikit-image) (2.22.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/carl69/anaconda3/envs/jupyter/lib/python3.9/site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/carl69/anaconda3/envs/jupyter/lib/python3.9/site-packages (from scikit-image) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/carl69/anaconda3/envs/jupyter/lib/python3.9/site-packages (from packaging>=20.0->scikit-image) (3.0.9)

# %%
# !wget "https://i.redd.it/1sme6te6knf01.jpg"
# Out:
# --2022-10-29 21:44:33--  https://i.redd.it/1sme6te6knf01.jpg
# Resolving i.redd.it (i.redd.it)... 2a04:4e42:65::396, 199.232.149.140
# Connecting to i.redd.it (i.redd.it)|2a04:4e42:65::396|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 188281 (184K) [image/jpeg]
# Saving to: ‘1sme6te6knf01.jpg’
#
# 1sme6te6knf01.jpg   100%[===================>] 183,87K  --.-KB/s    in 0,07s
#
# 2022-10-29 21:44:33 (2,65 MB/s) - ‘1sme6te6knf01.jpg’ saved [188281/188281]

# %%
import matplotlib.pyplot as plt

img_path = '1sme6te6knf01.jpg'

# %%
# Load with open-cv
import cv2
# open-cv represents RGB images as BGR (reverse order)
img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()

# %%
# Load with scikit
from skimage import io

img = io.imread(img_path)

plt.imshow(img)
plt.show()

# %%
# Load with PIL
from PIL import Image

img =  Image.open(img_path)

plt.imshow(img)
plt.show()
